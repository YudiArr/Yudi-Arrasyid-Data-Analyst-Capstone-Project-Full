# %% [markdown]
# # **JOBS API Implementation Using FLASK**

# %% [markdown]
# ## Objectives
#
# You will be executing this code  so that the client application **Collecting Jobs API**  will be accessing this code executing on the server

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: https://www.kaggle.com/promptcloud/jobs-on-naukricom under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %%
import flask
from flask import request, jsonify
import requests
import re
import os
import json

def get_data(key, value, current):
    results = list()
    pattern_dict = {
        'C': '(C)',
        'C++': '(C\\+\\+)',
        'Java': '(Java)',
        'C#': '(C\\#)',
        'Python': '(Python)',
        'Scala': '(Scala)',
        'Oracle': '(Oracle)',
        'SQL Server': '(SQL Server)',
        'MySQL Server': '(MySQL Server)',
        'PostgreSQL': '(PostgreSQL)',
        'MongoDB': '(MongoDB)',
        'JavaScript': '(JavaScript)',
        'Los Angeles': '(Los Angeles)',
        'New York': '(New York)',
        'San Francisco': '(San Francisco)',
        'Washington DC': '(Washington DC)',
        'Seattle': '(Seattle)',
        'Austin': '(Austin)',
        'Detroit': '(Detroit)',
    }
    for rec in current:
        if re.search(pattern_dict[value], rec[key]) is not None:
            results.append(rec)
    return results

app = flask.Flask(__name__)

# Download the JSON file using requests
datares = requests.get('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json')
data = datares.json()  # Directly load the JSON content

@app.route('/', methods=['GET'])
def home():
    return '''<h1>Welcome to Flask JOB search API</h1>'''

@app.route('/data/all', methods=['GET'])
def api_all():
    return jsonify(data)

@app.route('/data', methods=['GET'])
def api_id():
    res = None
    for req in request.args:
        if req == 'Job Title':
            key = 'Job Title'
        elif req == 'Job Experience Required':
            key = 'Job Experience Required'
        elif req == 'Key Skills':
            key = 'Key Skills'
        elif req == 'Role Category':
            key = 'Role Category'
        elif req == 'Location':
            key = 'Location'
        elif req == 'Functional Area':
            key = 'Functional Area'
        elif req == 'Industry':
            key = 'Industry'
        elif req == 'Role':
            key = 'Role'
        elif req == 'id':
            key = 'id'
        else:
            continue

        value = request.args[key]
        if res is None:
            res = get_data(key, value, data)
        else:
            res = get_data(key, value, res)

    return jsonify(res)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [27/May/2024 00:02:53] "GET /data?Key+Skills=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:53] "GET /data?Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:54] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=Python&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=Python&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=Python&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=Python&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=Python&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=Python&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=Python&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=C%23&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=C%23&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:55] "GET /data?Key+Skills=C%23&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%23&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%23&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%23&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%23&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%2B%2B&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%2B%2B&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%2B%2B&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%2B%2B&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%2B%2B&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%2B%2B&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=C%2B%2B&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=Java&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=Java&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:56] "GET /data?Key+Skills=Java&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=Java&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=Java&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=Java&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=Java&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=JavaScript&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=JavaScript&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=JavaScript&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=JavaScript&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=JavaScript&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=JavaScript&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=JavaScript&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=Python&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=Python&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=Python&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:57] "GET /data?Key+Skills=Python&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Python&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Python&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Python&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Scala&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Scala&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Scala&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Scala&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Scala&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Scala&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Scala&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Oracle&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Oracle&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Oracle&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Oracle&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Oracle&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:58] "GET /data?Key+Skills=Oracle&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=Oracle&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=SQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=SQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=SQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=SQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=SQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=SQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=SQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=MySQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=MySQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=MySQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=MySQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=MySQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=MySQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=MySQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=PostgreSQL&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:02:59] "GET /data?Key+Skills=PostgreSQL&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=PostgreSQL&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=PostgreSQL&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=PostgreSQL&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=PostgreSQL&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=PostgreSQL&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=MongoDB&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=MongoDB&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=MongoDB&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=MongoDB&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=MongoDB&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=MongoDB&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=MongoDB&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=C%23&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:00] "GET /data?Key+Skills=C%23&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%23&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%23&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%23&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%23&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%23&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%2B%2B&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%2B%2B&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%2B%2B&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%2B%2B&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%2B%2B&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%2B%2B&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=C%2B%2B&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=Java&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=Java&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:01] "GET /data?Key+Skills=Java&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=Java&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=Java&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=Java&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=Java&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=JavaScript&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=JavaScript&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=JavaScript&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=JavaScript&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=JavaScript&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=JavaScript&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=JavaScript&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=Python&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=Python&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=Python&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=Python&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:02] "GET /data?Key+Skills=Python&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Python&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Python&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Scala&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Scala&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Scala&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Scala&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Scala&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Scala&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Scala&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Oracle&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Oracle&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Oracle&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Oracle&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Oracle&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:03] "GET /data?Key+Skills=Oracle&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=Oracle&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=SQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=SQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=SQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=SQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=SQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=SQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=SQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=MySQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=MySQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=MySQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=MySQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=MySQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=MySQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=MySQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:04] "GET /data?Key+Skills=PostgreSQL&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=PostgreSQL&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=PostgreSQL&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=PostgreSQL&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=PostgreSQL&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=PostgreSQL&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=PostgreSQL&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=MongoDB&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=MongoDB&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=MongoDB&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=MongoDB&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=MongoDB&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=MongoDB&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:03:05] "GET /data?Key+Skills=MongoDB&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:41] "GET /data?Key+Skills=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:41] "GET /data?Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:42] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:43] "GET /data?Key+Skills=Python&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:43] "GET /data?Key+Skills=Python&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:43] "GET /data?Key+Skills=Python&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:43] "GET /data?Key+Skills=Python&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:43] "GET /data?Key+Skills=Python&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:43] "GET /data?Key+Skills=Python&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:43] "GET /data?Key+Skills=Python&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%23&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%23&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%23&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%23&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%23&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%23&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%23&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%2B%2B&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%2B%2B&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%2B%2B&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%2B%2B&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%2B%2B&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%2B%2B&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=C%2B%2B&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=Java&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:44] "GET /data?Key+Skills=Java&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=Java&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=Java&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=Java&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=Java&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=Java&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=JavaScript&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=JavaScript&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=JavaScript&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=JavaScript&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=JavaScript&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=JavaScript&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=JavaScript&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=Python&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=Python&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=Python&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:45] "GET /data?Key+Skills=Python&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Python&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Python&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Python&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Scala&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Scala&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Scala&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Scala&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Scala&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Scala&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Scala&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Oracle&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Oracle&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Oracle&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Oracle&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Oracle&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:46] "GET /data?Key+Skills=Oracle&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=Oracle&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=SQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=SQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=SQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=SQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=SQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=SQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=SQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=MySQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=MySQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=MySQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=MySQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=MySQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=MySQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=MySQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:47] "GET /data?Key+Skills=PostgreSQL&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=PostgreSQL&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=PostgreSQL&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=PostgreSQL&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=PostgreSQL&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=PostgreSQL&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=PostgreSQL&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=MongoDB&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=MongoDB&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=MongoDB&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=MongoDB&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=MongoDB&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=MongoDB&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=MongoDB&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=C%23&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=C%23&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=C%23&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:48] "GET /data?Key+Skills=C%23&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%23&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%23&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%23&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%2B%2B&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%2B%2B&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%2B%2B&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%2B%2B&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%2B%2B&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%2B%2B&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=C%2B%2B&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=Java&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=Java&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=Java&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=Java&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=Java&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:49] "GET /data?Key+Skills=Java&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=Java&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=JavaScript&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=JavaScript&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=JavaScript&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=JavaScript&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=JavaScript&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=JavaScript&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=JavaScript&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=Python&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=Python&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=Python&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=Python&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=Python&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=Python&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=Python&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:50] "GET /data?Key+Skills=Scala&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Scala&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Scala&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Scala&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Scala&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Scala&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Scala&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Oracle&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Oracle&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Oracle&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Oracle&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Oracle&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Oracle&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=Oracle&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=SQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=SQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=SQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:51] "GET /data?Key+Skills=SQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=SQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=SQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=SQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=MySQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=MySQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=MySQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=MySQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=MySQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=MySQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=MySQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=PostgreSQL&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=PostgreSQL&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=PostgreSQL&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=PostgreSQL&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=PostgreSQL&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=PostgreSQL&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=PostgreSQL&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:52] "GET /data?Key+Skills=MongoDB&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:53] "GET /data?Key+Skills=MongoDB&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:53] "GET /data?Key+Skills=MongoDB&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:53] "GET /data?Key+Skills=MongoDB&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:53] "GET /data?Key+Skills=MongoDB&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:53] "GET /data?Key+Skills=MongoDB&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2024 00:13:53] "GET /data?Key+Skills=MongoDB&Location=Detroit HTTP/1.1" 200 -
